# %% [markdown]
# # Speed dating data-set
# #### Joris Rombouts & Remco Surtel

# %% [markdown]
# ### 1.1 Visualization

# %% [markdown]
# ### <font color="green">Imports, preparation and configuration</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("speed_dating_assignment.csv")

# %% [markdown]
# ### <font color="green">Creating the visualization matrix</font>

# %%
# Add partner age (age_o) to the dataframe 
# by cross referencing: pid == iid
# first we copy the dataframe to a new dataframe, to change iid to pid 
# and to change age to age_o, so that we can merge them into the original dataframe
# we merge on pid
df_o = df.copy()
#only pick the iid and age columns
df_o = df_o.filter(items=['iid', 'age'])
#rename these to pid and age_o respectively
df_o.columns = ['pid', 'age_o']
#drop all duplicated pid's
df_o = df_o.drop_duplicates()
#merge the pid's and age-o's with old df to df_new
#merge on pid (because pid == iid)
df_matrix = pd.merge(df, df_o, on=['pid'], how = 'left')

# %%
#create visualization matrix showing the average decision made for each pair of ages
visualization_matrix = pd.crosstab(df_matrix['age'], df_matrix['age_o'], values = df_matrix['dec'], aggfunc=[np.mean])
#round values in matrix down to two decimals for readability
visualization_matrix = np.round(visualization_matrix, decimals=2)
#Convert ages shown in column and row names to integers
visualization_matrix.columns = [int(visualization_matrix.columns[i][1]) for i in range(0, len(visualization_matrix.columns))]
visualization_matrix.index = [int(visualization_matrix.index[i]) for i in range(0, len(visualization_matrix.index))]

# %%
cm = sns.light_palette("red", as_cmap=True)
s = visualization_matrix.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col2 {
#             background-color:  #ff9a9a;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col5 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col9 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col12 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col13 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col14 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col15 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col16 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col17 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col18 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col19 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col20 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col21 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col22 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row0_col23 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col0 {
#             background-color:  #ff0000;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col1 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col2 {
#             background-color:  #ffacac;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col3 {
#             background-color:  #ffa3a3;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col4 {
#             background-color:  #ffacac;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col8 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col10 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col12 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col13 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col14 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col15 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col16 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col17 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col18 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col19 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col20 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col21 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col22 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row1_col23 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col0 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col1 {
#             background-color:  #ffacac;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col2 {
#             background-color:  #ff4c4c;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col3 {
#             background-color:  #ff7e7e;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col4 {
#             background-color:  #ff8585;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col5 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col6 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col7 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col8 {
#             background-color:  #ff7272;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col10 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col12 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col13 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col14 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col15 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col16 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col17 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col18 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col19 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col20 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col21 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col22 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row2_col23 {
#             background-color:  #ffe5e5;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row3_col0 {
#             background-color:  #ffcece;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row3_col1 {
#             background-color:  #ff8282;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row3_col2 {
#             background-color:  #ff3e3e;
#         }    #T_f550a1be_d437_11e7_8cf9_6466b3bae413row3_col3 {
#             background-color:  #ff5757;
#         }    #T_f550a1be_d437_11e7_8c

# %% [markdown]
# ### <font color="green">Relations that we managed to discover</font>

# %% [markdown]
# First of all, note the presence of NaN values in the matrix. The speed dating data has been collected during an event in Boston over the course of two years. The rows represent the age of the subjects and the columns the ages of the date partners. The row and column labels are limited to the ages that are actually present in the dataset.  The presence of NaN values indicates that during the collection of speed dating data, not all subject-partner age pairs occurred in those two years. So, for example, it never occurred that an eighteen year-old went on a speed-date with another eighteen year-old.
#
# Moreover, there weren't many old participants in general, as evidenced by the lack of participants between ages 42 and 55. Therefore, in the process of discovering relations, we have tried to focus on ages that did have sufficiently many participants, roughly ages 20 through 35. We also mostly ignored values of 1 (meaning that all decisions for the corresponding pair of ages were positive), because in most cases this just meant that there were only one or two cases where two people of these ages met.
#
# Contrary to our initial expectations, the visualization does not show a clear line through the middle indicating that people are generally attracted to partners of the same age. What this does tell us, is that dating is more complicated than that. Matches cannot be determined only by age, there are certainly other significant factors to take into account.
#
# One relation that we can clearly see in the visualization though, is that there is a diverging trend. This indicates that, as people get older, they are attracted to a larger range of ages in their partners. This could be due to the age difference becoming less significant. For instance, when children start dating in high school, two years is a major difference. When you are in your thirties, however, two years isn't such a big deal anymore.
#
# Furthermore, the visualization shows another interesting phenomenon: the older the subject, the more willing they are to say yes. Or, in other words, older participants are more desperate to find a partner. A very clear example for this can be seen in row 39, where one participant said yes to every single potential partner.
