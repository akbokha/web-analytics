# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("speed_dating_assignment.csv")

# %%
#add partner age (age_o) to the dataframe 
#by cross referencing: pid == iid
#first we copy the dataframe to a new dataframe, to change iid to pid 
# and to change age to age_o, so that we can merge them into the original dataframe
# we merge on pid
df_o = df.copy()
#only pick the iid and age columns
df_o = df_o.filter(items=['iid', 'age'])
#rename these to pid and age_o respectively
df_o.columns = ['pid', 'age_o']
#drop all duplicated pid's
df_o = df_o.drop_duplicates()
#merge the pid's and age-o's with old df to df_new
#merge on pid (because pid == iid)
df_new = pd.merge(df, df_o, on=['pid'], how = 'left')

# %%
#now we need to generate age_o by cross referencing pid == id
df_matrix = pd.merge(df_new, df_o, on=['pid'], how='left')

# %%
visualization_matrix = pd.crosstab(df_matrix['age'], df_matrix['age_o'], values = df_matrix['dec'], aggfunc=[np.sum])

# %%
cm = sns.light_palette("red", as_cmap=True)
s = visualization_matrix.style.background_gradient(cmap=cm)
s
# Out:
# C:\Users\Joris\Anaconda3\lib\site-packages\matplotlib\colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)
# <style  type="text/css" >
#     #T_becf809c_d061_11e7_b65e_104a7d536785row0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col2 {
#             background-color:  #ffc9c9;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col5 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col9 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col11 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col12 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col13 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col14 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col15 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col16 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col17 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col18 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col19 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col20 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col21 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col22 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row0_col23 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col0 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col1 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col2 {
#             background-color:  #ffc9c9;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col3 {
#             background-color:  #ffcece;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col4 {
#             background-color:  #ffe0e0;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col8 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col10 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col11 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col12 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col13 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col14 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col15 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col16 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col17 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col18 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col19 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col20 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col21 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col22 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row1_col23 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col0 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col1 {
#             background-color:  #ffacac;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col2 {
#             background-color:  #ff7272;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col3 {
#             background-color:  #ffa9a9;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col4 {
#             background-color:  #ffc8c8;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col5 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col6 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col7 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col8 {
#             background-color:  #ffe2e2;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col10 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col11 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col12 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col13 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col14 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col15 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col16 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col17 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col18 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col19 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col20 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col21 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col22 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row2_col23 {
#             background-color:  #ffe5e5;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row3_col0 {
#             background-color:  #ff0000;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row3_col1 {
#             background-color:  #ff3939;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row3_col2 {
#             background-color:  #ff0000;
#         }    #T_becf809c_d061_11e7_b65e_104a7d536785row3_col3 {
#             background-color:  #ff2424;
#         }    #T_becf809c_d061_11e7_b6
