# %% [markdown]
# # Web Analytics (2IID0) Homework Assignment 3
# ## Exceptional Model Ming vs A/B Testing
# #### <i>Abdel K. Bokharouss, Bart van Helvert, Joris Rombouts & Remco Surtel</i>   -   December 2017

# %% [markdown]
# In this assignment we will combine Exceptional Model Mining (EMM) and A/B Testing. The dataset has been provided by StudyPortals. The core concept of A/B Testing is that each test subject gets a corresponding variant assigned. After that, we measure the rate of success per variant and the variant with most success is kept, while the other is discarded. However, subgroups that might be served better by the losing version will be disadvantaged. To do better than this, we further mine the data to find coherent subgroups where alternative delivers more success. New visitors to the website that correspond to a specific subgroup, will get either version A or B of the website. Exceptional Model Mining allows us to mine the data further, so that we can discover these subgroups. First, we need to make a decision which attributes will be used as descriptors and which of the attributes will be used as targets.

# %% [markdown]
# ### <font color="green">imports, preparation and configuration</font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1 Data Preprocessing

# %% [markdown]
# <b><i>a. Which columns, available in which of the input files, must we designate as our targets in the EMM process?</i></b><br>
# The raw data that StudyPortals delivered, contains of three datasets: `clicking_data`, `experiment_details` and `meta_data`. The primary imporance to StudyPortals is analyzing the association between which version of the website were shown (version A or B) and whether or not the user clicked on the button. Therefore the binary attribute `action` of the dataset `clicking_data` is the first target attribute we define. However, we also want to know which version (A or B) was showed to the user. Therefore the attribute `condition` of the dataset `experiment_details` is the second target attribute we define.

# %% [markdown]
# <b><i>b.</i></b><br>After the targets are defined, the next step to do is to select which attributes will be used as descriptors. The goal is to gather as much descriptor informaiton as is reasonably possible. First we explore the data, and check how many NAN-values the three datasets contain.

# %%
df_click = pd.read_csv('data/clicking_data.csv')
df_click.head()
# Out:
#   action action_label action_type      tstamp  \
# 0   clic      revenue        link  1472755490
# 1   clic      revenue        link  1472839117
# 2   clic      revenue        link  1472879219
# 3   clic      revenue        link  1472890876
# 4   clic      revenue        link  1472892380
#
#                            user_session
# 0  379881d5-32d7-49f4-bf5b-81fefbc5fcce
# 1  2a0f4218-4f62-479b-845c-109b2720e6e7
# 2  a511b6dc-2dca-455b-b5e2-bf2d224a5505
# 3  9fb616a7-4e13-4307-ac92-0b075d7d376a
# 4  64816772-688d-4460-a591-79aa49bba0d5

# %%
df_click.shape
# Out:
# (919, 5)

# %%
df_click.user_session.describe()
# Out:
# count                                      919
# unique                                     778
# top       8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# freq                                        17
# Name: user_session, dtype: object

# %%
df_click.loc[df_click.user_session == '8ab1e096-cbf3-4484-bacd-01a833e3e0fd']
# Out:
#     action action_label action_type      tstamp  \
# 94    view      premium         org  1472891985
# 95    view      premium         org  1472892049
# 274   view      premium         org  1472806209
# 296   view      premium         org  1472887685
# 297   view      premium         org  1472887801
# 298   view      premium         org  1472887848
# 300   view      premium         org  1472891365
# 301   view      premium         org  1472891381
# 402   view      premium         org  1472887207
# 403   view      premium         org  1472887330
# 404   view      premium         org  1472888028
# 405   view      premium         org  1472890822
# 408   view      premium         org  1472891706
# 716   view      premium         org  1472886847
# 718   view      premium         org  1472887667
# 719   view      premium         org  1472888326
# 721   view      premium         org  1472890915
#
#                              user_session
# 94   8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 95   8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 274  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 296  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 297  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 298  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 300  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 301  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 402  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 403  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 404  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 405  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 408  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 716  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 718  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 719  8ab1e096-cbf3-4484-bacd-01a833e3e0fd
# 721  8ab1e096-cbf3-4484-bacd-01a833e3e0fd

# %%
pd.concat(g for _, g in df_click.groupby("user_session") if len(g) > 1)
# Out:
#     action action_label action_type      tstamp  \
# 333   clic      revenue        link  1473024926
# 764   view      premium         org  1473024321
# 168   view      premium         org  1473114699
# 789   view      premium         org  1473114419
# 22    clic      revenue        link  1473103156
# 476   view      premium         org  1473103043
# 448   view      premium         org  1473030266
# 765   view      premium         org  1473030324
# 241   view      premium         org  1473365377
# 250   view      premium         org  1474572550
# 316   clic      revenue        link  1473366025
# 328   clic      revenue        link  1472996228
# 755   view      premium         org  1472988585
# 340   clic      revenue        link  1473111784
# 485   view      premium         org  1473111764
# 57    view      premium         org  1472788305
# 270   view      premium         org  1472789955
# 35    clic      revenue        link  1473291469
# 222   view      premium         org  1473291728
# 223   view      premium         org  1473291831
# 647   view      premium         org  1473291586
# 851   view      premium         org  1473291466
# 373   view      premium         org  1472792481
# 374   view      premium         org  1472792572
# 339   clic      revenue        link  1473106196
# 477   view      premium         org  1473106102
# 173   view      premium         org  1473143088
# 590   view      premium         org  1473138040
# 591   view      premium         org  1473143058
# 355   clic      revenue        link  1473323937
# ..     ...          ...         ...         ...
# 352   clic      revenue        link  1473266426
# 233   view      premium         org  1473343642
# 234   view      premium         org  1473343694
# 865   view      premium         org  1473343756
# 69    view      premium         org  1472823529
# 70    view      premium         org  1472823952
# 498   view      premium         org  1473176595
# 808   view      premium         org  1473176434
# 102   view      premium         org  1472916736
# 104   view      premium         org  1472917770
# 105   view      premium         org  1472917891
# 680   view      premium         org  1473704167
# 863   view      premium         org  1473343661
# 864   view      premium         org  1473343678
# 33    clic      revenue        link  1473266707
# 638   view      premium         org  1473266647
# 185   view      premium         org  1473177722
# 603   view      premium         org  1473177631
# 6     clic      revenue        link  1472899052
# 411   view      premium         org  1472901782
# 478   view      premium         org  1473106298
# 479   view      premium         org  1473106307
# 841   view      premium         org  1473243705
# 842   view      premium         org  1473243707
# 367   view      premium         org  1472762587
# 368   view      premium         org  1472762604
# 23    clic      revenue        link  1473107807
# 786   view      premium         org  1473107575
# 320   clic      revenue        link  1472744893
# 684   view      premium         org  1472744639
#
#                              user_session
# 333  007f8a0c-e8ad-4268-a818-eaf0723aecba
# 764  007f8a0c-e8ad-4268-a818-eaf0723aecba
# 168  02cca032-cdc2-4e41-87d6-9edf4c7c6706
# 789  02cca032-cdc2-4e41-87d6-9edf4c7c6706
# 22   06b119f3-3ced-44df-bf1f-f1b1ae75f515
# 476  06b119f3-3ced-44df-bf1f-f1b1ae75f515
# 448  07ed74dd-4db7-4a31-aa5d-a24ad80bc01d
# 765  07ed74dd-4db7-4a31-aa5d-a24ad80bc01d
# 241  081e0fd6-6385-4228-b2c9-8e90b905c076
# 250  081e0fd6-6385-4228-b2c9-8e90b905c076
# 316  081e0fd6-6385-4228-b2c9-8e90b905c076
# 328  0a47f8a7-a8d5-4013-9c5d-2a7a09c53e0c
# 755  0a47f8a7-a8d5-4013-9c5d-2a7a09c53e0c
# 340  0bd16e9d-3928-4822-9d5d-7b229ed6329c
# 485  0bd16e9d-3928-4822-9d5d-7b229ed6329c
# 57   0df1a4d2-1d98-40b0-9f37-588fc7ebd848
# 270  0df1a4d2-1d98-40b0-9f37-588fc7ebd848
# 35   0f714ca3-622d-4acd-b9f2-ac5a517cd989
# 222  0f714ca3-622d-4acd-b9f2-ac5a517cd989
# 223  0f714ca3-622d-4acd-b9f2-ac5a517cd989
# 647  0f714ca3-622d-4acd-b9f2-ac5a517cd989
# 851  0f714ca3-622d-4acd-b9f2-ac5a517cd989
# 373  10094519-9aa0-4665-a099-634a7311fb8f
# 374  10094519-9aa0-4665-a099-634a7311fb8f
# 339  13803de7-4d41-4170-8ae3-ff21a06acd69
# 477  13803de7-4d41-4170-8ae3-ff21a06acd69
# 173  13a8dbba-e20f-42e6-a828-038aff32a6a8
# 590  13a8dbba-e20f-42e6-a828-038aff32a6a8
# 591  13a8dbba-e20f-42e6-a828-038aff32a6a8
# 355  17928495-7a0c-4461-98f8-0e3af8996904
# ..                                    ...
# 352  dfedab4c-c2eb-40c8-a9bc-bdf9c36b9877
# 233  e74fc785-2ce1-4db2-98ef-af0d5b4e159c
# 234  e74fc785-2ce1-4db2-98ef-af0d5b4e159c
# 865  e74fc785-2ce1-4db2-98ef-af0d5b4e159c
# 69   e87aa080-5405-4765-933a-fa9d6422ce66
# 70   e87aa080-5405-4765-933a-fa9d6422ce66
# 498  ec12d3ca-a9d3-40fb-a2d5-8e047e21678e
# 808  ec12d3ca-a9d3-40fb-a2d5-8e047e21678e
# 102  ec476328-261a-4d1e-ba5d-777aa094e855
# 104  ec476328-261a-4d1e-ba5d-777aa094e855
# 105  ec476328-261a-4d1e-ba5d-777aa094e855
# 680  ed1b6397-0c3d-4efe-9e2f-f448b60a7384
# 863  ed1b6397-0c3d-4efe-9e2f-f448b60a7384
# 864  ed1b6397-0c3d-4efe-9e2f-f448b60a7384
# 33   f2f510a9-3183-470d-a909-d0c760d35fdb
# 638  f2f510a9-3183-470d-a909-d0c760d35fdb
# 185  f3a41049-15e6-4060-af49-d317dfa7837e
# 603  f3a41049-15e6-4060-af49-d317dfa7837e
# 6    f634a585-abf5-4d7b-9226-8d0cc4a3bd60
# 411  f634a585-abf5-4d7b-9226-8d0cc4a3bd60
# 478  f66d3f75-361c-4fb1-9c50-d1df14cb8687
# 479  f66d3f75-361c-4fb1-9c50-d1df14cb8687
# 841  f9959df4-ae14-4a88-8da8-0348baa96792
# 842  f9959df4-ae14-4a88-8da8-0348baa96792
# 367  fd7278b5-eddc-47de-8e65-9b0f84882cc5
# 368  fd7278b5-eddc-47de-8e65-9b0f84882cc5
# 23   feaa4730-52ea-48a1-9c7e-768cdfb123c4
# 786  feaa4730-52ea-48a1-9c7e-768cdfb123c4
# 320  ff46cd79-b474-46d9-a156-65b74c942988
# 684  ff46cd79-b474-46d9-a156-65b74c942988
#
# [235 rows x 5 columns]

# %%
df_click.info()

# %%
df_experiment = pd.read_csv('data/experiment_details_new.csv')
df_experiment.head()
# Out:
#                                 user_id          experiment_id  \
# 0  7794c3b2-4d08-4bb8-bfc9-b50935fed1fc  86-v2-Butonny buttons
# 1  0baf5074-74bd-4257-ac9f-a07d25f37667  86-v2-Butonny buttons
# 2  623d19a6-64b4-412a-8143-750995742605  86-v2-Butonny buttons
# 3  d4b62fc9-dead-441f-936a-db08c2711a1e  86-v2-Butonny buttons
# 4  8de611c2-0e10-4f63-a016-0f1bd7a683e1  86-v2-Butonny buttons
#
#                       condition            collector_tstamp
# 0                     1-Control  2016-09-01 12:21:25.716000
# 1  2-Buttony-Conversion-Buttons  2016-09-01 12:22:01.726000
# 2  2-Buttony-Conversion-Buttons  2016-09-01 12:22:31.797000
# 3  2-Buttony-Conversion-Buttons  2016-09-01 12:22:53.218000
# 4                     1-Control  2016-09-01 12:24:15.978000

# %%
df_experiment.loc[df_experiment.user_id == "8ab1e096-cbf3-4484-bacd-01a833e3e0fd"]
# Out:
#                                     user_id          experiment_id  condition  \
# 593    8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 1031   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 2964   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 2979   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 2982   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 6879   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 6886   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 6905   8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 11309  8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 11890  8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
# 11897  8ab1e096-cbf3-4484-bacd-01a833e3e0fd  86-v2-Butonny buttons  1-Control
#
#                  collector_tstamp
# 593    2016-09-02 08:50:27.865000
# 1031   2016-09-03 08:05:36.112000
# 2964   2016-09-03 07:40:11.146000
# 2979   2016-09-03 08:12:13.334000
# 2982   2016-09-03 08:13:41.091000
# 6879   2016-09-03 07:20:33.206000
# 6886   2016-09-03 07:40:13.986000
# 6905   2016-09-03 08:27:41.687000
# 11309  2016-09-01 23:55:20.910000
# 11890  2016-09-03 07:14:22.320000
# 11897  2016-09-03 07:39:07.595000

# %%
df_experiment['count'] = 1

# %%
test = df_experiment.pivot_table(index='user_id',columns='condition',aggfunc=sum)
test.fillna(0, inplace = True)
test["two_versions_one_userid"] = np.where((((test[('count', '1-Control')] > 0) & (test[('count', '2-Buttony-Conversion-Buttons')] == 0)) |
                                            ((test[('count', '1-Control')] == 0) & (test[('count', '2-Buttony-Conversion-Buttons')] > 0))), 0, 1)

# %%
have_seen_two_versions = re
one = list(have_seen_two_versions.index.unique())

# %%
two = list(df_click.user_session.unique())

# %%
list(set(one) & set(two))
# Out:
# ['0d44242b-bd92-4f38-bb04-6ef1d5890fd6',
#  'c2bde2e2-d0e0-476b-8a48-78529cb4c5d0',
#  '10094519-9aa0-4665-a099-634a7311fb8f',
#  '1a491e50-5b0c-46c6-81b9-5dd8e3c21d51',
#  'd9db6db7-bf57-46d1-994f-82bedea5ad26',
#  'ddc9391b-08b6-460f-a37c-261bd58ea3d9',
#  '17bc8bf8-e432-4577-8667-f6f310149f04',
#  '1a296072-dd42-4158-8c1d-be82d5fdf80f',
#  'bedecc9a-22d0-422c-80ac-2ba13fdfbbf2',
#  '03af59ca-fb4f-4fda-ad44-e6f8bfc13151',
#  'f08a611c-7f09-45dd-bb8d-8af9a5300ced',
#  'aad247eb-57bf-46eb-b865-ed2d047d2db5',
#  '26660906-5f26-4f32-8d75-9b912bbe83af',
#  '985b802b-edbe-4168-ac39-87eae3ce5042',
#  '6d9ad57d-3deb-4987-b171-1fa42bce607d',
#  'f72aab36-93b1-46a2-9d0c-60ecb07f9eca']

# %%
test.columns.values
# Out:
# array([('count', '1-Control'), ('count', '2-Buttony-Conversion-Buttons')], dtype=object)

# %%
df_experiment.user_id.describe()
# Out:
# count                                    14764
# unique                                    9360
# top       0df1a4d2-1d98-40b0-9f37-588fc7ebd848
# freq                                       185
# Name: user_id, dtype: object

# %%
df_experiment.rename(columns={'timestamp':'etl_tstamp'}, inplace=True)

# %%
df_experiment.info()

# %%
df_meta = pd.read_csv('data/meta_data_modified.csv', encoding = 'ansi')
df_meta.head()
# Out:
#   platform etl_tstamp collector_tstamp dvce_created_tstamp      event  \
# 0      web    06:22.2          06:33.7             06:26.2  page_ping
# 1      web    06:49.2          07:00.2             06:52.6  page_ping
# 2      web    07:09.2          07:20.1             07:12.6  page_ping
# 3      web    09:49.3          10:01.0             09:53.4  page_ping
# 4      web    10:40.3          10:51.8             10:44.4  page_ping
#
#                           domain_userid                      domain_sessionid  \
# 0  e8702985-ffee-4ede-a89f-396312539812  0ca47d52-1375-4346-ab2e-b205b64f642e
# 1  e8702985-ffee-4ede-a89f-396312539812  0ca47d52-1375-4346-ab2e-b205b64f642e
# 2  e8702985-ffee-4ede-a89f-396312539812  0ca47d52-1375-4346-ab2e-b205b64f642e
# 3  e8702985-ffee-4ede-a89f-396312539812  0ca47d52-1375-4346-ab2e-b205b64f642e
# 4  e8702985-ffee-4ede-a89f-396312539812  0ca47d52-1375-4346-ab2e-b205b64f642e
#
#                                 user_id geo_country geo_region    ...      \
# 0  bc5effb7-a476-414f-a62e-5479022e7553          GR               ...
# 1  bc5effb7-a476-414f-a62e-5479022e7553          GR               ...
# 2  bc5effb7-a476-414f-a62e-5479022e7553          GR               ...
# 3  bc5effb7-a476-414f-a62e-5479022e7553          GR               ...
# 4  bc5effb7-a476-414f-a62e-5479022e7553          GR               ...
#
#   pp_yoffset_max                                          useragent  \
# 0          915.0  Mozilla/5.0 (Linux; Android 4.4.4; GT-I9300 Bu...
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3         3411.0  Mozilla/5.0 (Linux; Android 4.4.4; GT-I9300 Bu...
# 4            NaN                                                NaN
#
#   browser_language browser_cookies browser_colordepth browser_viewdepth  \
# 0              NaN             NaN                NaN               NaN
# 1              NaN             NaN                NaN               NaN
# 2              NaN             NaN                NaN               NaN
# 3              NaN             NaN                NaN               NaN
# 4              NaN             NaN                NaN               NaN
#
#   browser_viewheight  os_name  os_timezone  dvce_type
# 0                NaN      NaN          NaN        NaN
# 1                NaN      NaN          NaN        NaN
# 2                NaN      NaN          NaN        NaN
# 3                NaN      NaN          NaN        NaN
# 4                NaN      NaN          NaN        NaN
#
# [5 rows x 30 columns]

# %%
df_meta

# %%
df_meta.info()

# %%
sum(df_meta.apply(lambda x: sum(x.isnull().values), axis = 1) > 0) # number of rows with NaN values

# %% [markdown]
# This whole assignment is about the analysis of the behavior of visitors in terms of an unusual association between which version of the website they were shown (version A or B) and whether or not they clicked on a particular button. Before we actually make an assesment of the best possible strategy for the missing values, we first need to evaluate the volume and completeness of the attributes which identify a specific visitor since the visitors are at the core of this analysis.

# %%
df_meta[['domain_userid', 'domain_sessionid', 'user_id']].apply(
    pd.Series.nunique) # unique number of values for each column

# %%
"unique user-sessions in click data: ", len(df_click.user_session.unique())

# %%
"unique user-id's in experiment data: ", len(df_experiment.user_id.unique())

# %% [markdown]
# Each user is identified with a unique user id and each visit is idenitified by a unique user session. Since we are interested in whether an user which visits the website in a certain version, clicks on a particular button or not during a session, we want to limt ourselves to the session id's for which action labels are availabe. We can see that the number of user-id's and session-id's in the three different datasets are not in line with eachother. The goal is to acquire a dataframe in which we have for each user session and id, the experiment details and all the relevant information we can obtain from the meta data file.

# %%
overlap = list(set(df_experiment.columns) & set(df_meta.columns))

# %%
len(list(set(df_meta.user_id.values) & set(df_experiment.user_id.values)))

# %%
#len(list(set(df_meta.collector_tstamp.values) & set(df_experiment.timestamp.values)))

# %%
df_experiment.shape, df_meta.shape

# %% [markdown]
# Tara from study_portals: <i>"Timestamp in the experiment file indicates the timestamp that the users starts the session while seeing the variation A or B. I recommend you to use the meta-data timestamp for your further analysis. "</i>

# %%
session_action = df_experiment.merge(df_meta, on = overlap, how = 'left')
session_action.info()

# %%
len(list(set(df_meta.user_id.values) & set(df_click.user_session.values)))

# %%
session_action = session_action.merge(df_click, how = 'left', left_on = 'user_id', right_on = 'user_session')

# %%
session_action = session_action[pd.notnull(session_action['action'])] # not sure whether absence implies no click

# %%
session_action.info()

# %% [markdown]
# ### 2 A&B Testing

# %% [markdown]
# ### 3 Beyond A&B Testing
